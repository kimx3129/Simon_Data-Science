# %% [markdown]
# # Face Detection

# %%
import numpy as np
import cv2
import warnings
import matplotlib.pyplot as plt

# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
def display(img, cmap='gray'):
    fig = plt.figure(figsize = (11,9))
    ax = fig.add_subplot(111)
    ax.imshow(img, cmap = 'gray')

# %%
denis = cv2.imread('Computer-Vision-with-Python/DATA/Denis_Mukwege.jpg',0)
solvay = cv2.imread('Computer-Vision-with-Python/DATA/solvay_conference.jpg',0)

# %% [markdown]
# ## Define cascade from haar cascade

# %%
face_cascade = cv2.CascadeClassifier('Computer-Vision-with-Python/DATA/haarcascades/haarcascade_frontalface_default.xml')

# %%
def detect_face(img):
    face_img = img.copy()
    
    face_rect = face_cascade.detectMultiScale(face_img)
    
    for (x,y,w,h) in face_rect:
        cv2.rectangle(face_img, (x,y), (x+w,y+h), (255,255,255), 10)
        
    return face_img

# %%
result = detect_face(denis)

# %%
display(result)

# %% [markdown]
# ### Detect many faces (not works well)

# %%
result = detect_face(solvay)
display(result)

# %% [markdown]
# ## Adj Face Detection

# %% [markdown]
# Apply scaleFactor and min number of neighbors

# %%
def adj_detect_face(img):
    face_img = img.copy()
    
    face_rect = face_cascade.detectMultiScale(face_img, scaleFactor = 1.12, minNeighbors = 6)
    
    for (x,y,w,h) in face_rect:
        cv2.rectangle(face_img, (x,y), (x+w,y+h), (255,255,255), 10)
        
    return face_img

# %%
result = adj_detect_face(solvay)
display(result)
